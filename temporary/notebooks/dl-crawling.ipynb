# %% [markdown]
# # Note
# Import this notebook to kaggle or google drive and run

# %% [markdown]
# # Your configuration

# %% [markdown]
# You have to provide your github access token to access to this repository

# %%
### Your github token with repo privilege
git_access_token = "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"

is_kaggle = True

# %% [markdown]
# # Installation

# %%
from git import Repo

repo = Repo.clone_from(f"https://{git_access_token}:x-oauth-basic@github.com/DungNasSa10/Deep-Learning-Project-2022-1.git", './crawl')
repo.git.checkout('crawl')
# Out:
# "Branch 'crawl' set up to track remote branch 'crawl' from 'origin'."

# %%
# %cd crawl 
# !mkdir logs
# Out:
# /kaggle/working/crawl

# %%
# !pip3 install --force-reinstall torch==1.12.0 torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu116
# !pip3 install -r requirements.txt

# %% [markdown]
# # Crawl pipeline
# Command:
# ```
# usage: crawl.py [-h] -f FILEPATH_OR_URL [-d SAVE_DIR] [-sr SAMPLING_RATE] [-rm REMOVE_MP3] [-l TIME_LIMIT]
#
# optional arguments:
#   -h, --help            show this help message and exit
#   -f FILEPATH_OR_URL, --filepath_or_url FILEPATH_OR_URL
#                         Can be file path or google drive shared url
#   -d SAVE_DIR, --save_dir SAVE_DIR
#                         Directory to save .wav files
#   -sr SAMPLING_RATE, --sampling_rate SAMPLING_RATE
#                         Sampling rate of output .wav files
#   -rm REMOVE_MP3, --remove_mp3 REMOVE_MP3
#                         Remove downloaded mp3
#   -l TIME_LIMIT, --time_limit TIME_LIMIT
#                         time limit in seconds
# ```
#
# Example:
# ```
# !python src/crawl.py \
# -f https://drive.google.com/file/d/1BL4tkLkPPDeuYwlCaMvIrKYCst8E4zEN/view?usp=share_link \
# -d /kaggle/working/output/ \
# -sr 16000 \
# -l 60
# ```
# ## **NOTE**:
# If cpu is used, time limit should be 41400, otherwise time limit should be 42600

# %%
# !python src/crawl.py \
-f https://drive.google.com/file/d/1BL4tkLkPPDeuYwlCaMvIrKYCst8E4zEN/view?usp=share_link \
-d /kaggle/working/output/ \
-sr 16000 \
-l 60

# %%
if is_kaggle:
    # !mv output /kaggle/working/output
    print("Zip save directory: /kaggle/working/output/")
    # !zip -r /kaggle/working/output.zip /kaggle/working/output/
    print("Remove directory: /kaggle/working/output/")
    # !rm -r /kaggle/working/output/
