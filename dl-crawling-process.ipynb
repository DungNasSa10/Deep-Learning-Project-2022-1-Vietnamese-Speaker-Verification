# %% [markdown]
# # Note
# Import this notebook to kaggle or google colab and run

# %% [markdown]
# # Your configuration

# %% [markdown]
# You have to provide your github access token to access to this repository

# %%
### Your github token with repo privilege
git_access_token = ""

### Your public csv file on google drive that contains voice names and url videos 
### this file is Voice List - Long.csv
gg_drive_csv_url = 'https://drive.google.com/file/d/1yNXM_5DT-iaFhzlTMklUP86OOdATe293/view?usp=share_link'

is_kaggle = True
save_directory = "/kaggle/working/output/"

# %% [markdown]
# # Installation

# %%
from git import Repo

repo = Repo.clone_from(f"https://{git_access_token}:x-oauth-basic@github.com/DungNasSa10/Deep-Learning-Project-2022-1.git", './crawl')
repo.git.checkout('crawl')
# Out:
# "Branch 'crawl' set up to track remote branch 'crawl' from 'origin'."

# %%
# %cd crawl 
# !mkdir logs
# Out:
# /kaggle/working/crawl

# %%
# !pip3 install --force-reinstall torch==1.12.0 torchvision torchaudio --extra-index-url https://download.pytorch.org/whl/cu116
# !pip3 install -r requirements.txt

# %% [markdown]
# # Crawl pipeline

# %%
import os, sys
sys.path.append(os.path.join(os.getcwd(), "src"))

from tqdm import tqdm
from functools import partialmethod

tqdm.__init__ = partialmethod(tqdm.__init__, disable=True)

from crawling.pipeline import Pipeline
pipe = Pipeline()
pipe.run(gg_drive_csv_url, save_dir=save_directory)

# %%
if is_kaggle:
    import shutil
    print("Zip save directory:", save_directory)
    print("Zip status:", os.system(f"zip -r ../output.zip {save_directory}"))
    print("Remove directory:", save_directory)
    shutil.rmtree(save_directory)
